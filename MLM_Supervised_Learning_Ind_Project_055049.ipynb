# %% [markdown]
# # **Supervised Learning Models on Import-Export Dataset using Python**
#
#
#
# ---
#
#
#
# ## **PROJECT CONTENTS:**
# - Project Information
# - Description of Data
# - Data Sampling
# - Project Objectives | Problem Statements
# - Analysis of Data
# - Observations | Findings
# - Managerial Insights | Recommendations
#
# ---
#
# ### **1. Project Information**
# - **Title**: Building Supervised Learning Models using Python: Classification & Regression {Logistic Regression | Decision Trees}
# - **Student Name**: Suvra Datta Banik (055049)
#
# ---
#
# ### **2. Description of Data**
# - **Data Source**: https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000
#
#   A live link is used in the dataset
#
# - **Data Columns Description**:
#   - **Transaction_ID**: Unique identifier for each trade transaction.
#   - **Country**: Country of origin or destination for the trade.
#   - **Product**: Product being traded.
#   - **Import_Export**: Indicates whether the transaction is an import or export.
#   - **Quantity**: Amount of the product traded.
#   - **Value**: Monetary value of the product in USD.
#   - **Date**: Date of the transaction.
#   - **Category**: Category of the product (e.g., Electronics, Clothing, Machinery).
#   - **Port**: Port of entry or departure.
#   - **Customs_Code**: Customs or HS code for product classification.
#   - **Weight**: Weight of the product in kilograms.
#   - **Shipping_Method**: Method used for shipping (e.g., Air, Sea, Land).
#   - **Supplier**: Name of the supplier or manufacturer.
#   - **Customer**: Name of the customer or recipient.
#   - **Invoice_Number**: Unique invoice number for the transaction.
#   - **Payment_Terms**: Terms of payment (e.g., Net 30, Net 60, Cash on Delivery).
#
# - **Data Type**: Since the dataset contains multiple entities (countries) and records data over time, this is an example of Panel Data (also called longitudinal data).
#
# - **Data Variables**:
#   - **All non-null Variables**
#     - **Numbers**:
#       - Integer Variables: 3 (Quantity, Customs_Code, Invoice_Number)
#       - Float (Decimal) Variables: 2 (Value, Weight)
#     - **Text**: 9 (Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customer, Payment_Terms)
#     - **DateTime**: 1 (Date)
#
#   The dataset used for this analysis is a sample of 5001 records extracted from a larger dataset containing 15,000 records of import-export transactions. The data includes information on various aspects of trade, such as:
#  - **Transaction Details**: Transaction ID, Invoice Number, Date
#  - **Product Information**: Product, Category, Customs Code, Quantity, Value, Weight
#  - **Trade Information**: Country, Import/Export, Port, Shipping Method, Supplier, Customer, Payment Terms
#
#  The data represents panel data (longitudinal data) as it tracks multiple entities (countries) over time. The variables in the dataset are classified as:
#  - **Index Variables**: Transaction ID, Invoice Number
#  - **Categorical Variables**: Country, Product, Import/Export, Category, Port, Shipping Method, Supplier, Customs Code, Customer, Payment Terms
#  - **Non-Categorical Variables**: Quantity, Value, Weight
#
# ---
#
# ### **3. Data Sampling**
# From the dataset containing 15,000 values, a sample of 5001 entries was taken. The dataset sample (now referred to as `sdb49_sample`) was taken into account for further exploration.
#
# - **Data Variables**:
#   - **Index Variables**: 'Transaction_ID', 'Invoice_Number'
#   - **Categorical Variables**:
#     - Nominal Variables: Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customs_Code, Customer
#     - Ordinal Variable: Payment_Terms
#   - **Non-Categorical Variables**: Quantity, Value, and Weight
#
# ---
#
# ### **4. Project Objectives**
# The main objectives of this data analysis are:
#  - **Classification/Clustering**: To classify or cluster the dataset into segments using supervised learning algorithms to identify patterns and relationships in the data.
#  - **Feature Identification**: To determine the most significant variables or features that contribute to the classification or clustering.
#  - **Model Selection**: To identify the most appropriate classification model based on performance metrics like accuracy, precision, recall, and F1-score.
#
#
# ---
#
# ### **5. Exploratory Data Analysis**
# #### **5.1. Data Preprocessing:**
# - The data has no missing values, hence no missing data treatment was performed.
# - For Encoding, **Ordinal Encoder** was used.
# - For Scaling, **Min-Max Scaler** was used.
#
# #### **5.2. Descriptive Statistics**
# - **Non-Categorical Variables**:
#   - Measures of Central Tendency: Minimum, Maximum, Mean, Median, Mode, Percentile
#   - Measures of Dispersion: Range, Standard Deviation, Skewness, Kurtosis, Correlation (Matrix)
#   - Composite Measure: Coefficient of Variation, Confidence Interval
#
# - **Categorical Variables**:
#   - Count, Frequency, Proportion, Minimum, Maximum, Mode, Rank
#
# #### **5.3. Data Visualization**
# - Various subplots were used such as Bar, Heatmaps, Histograms, and Correlation Matrices.
#
# #### **5.4. Inferential Statistics**
# - **Categorical Variable** (Nominal | Ordinal):
#   - Test of Homogeneity (Chi-sq)
# - **Non-Categorical Variable**:
#   - Test of Normality (Shapiro-Wilk, Kolmogorov-Smirnov, Anderson-Darling, Jarque-Bera)
#   - Test of Correlation (t)
#
# #### **5.5. Machine Learning Models**
#
# - **Logistic Regression (LR)**:
#   Logistic regression is a classification algorithm that models the probability of a binary outcome based on one or more predictor variables using a logistic function.
#
# - **Support Vector Machines (SVM)**:
#   SVM finds a hyperplane that best separates the data into classes by maximizing the margin between the closest points of the classes (support vectors).
#
# - **Stochastic Gradient Descent (SGD)**:
#   An iterative optimization algorithm used for minimizing loss functions in linear classifiers and regressors, particularly useful for large datasets.
#
# - **Decision Trees**:
#   A tree-based algorithm where each internal node represents a decision on a feature, each leaf node represents an outcome, and paths from root to leaf represent classification rules.
#
# - **K-Nearest Neighbors (KNN)**:
#   A lazy learning algorithm that classifies a data point based on the majority class of its k-nearest neighbors in the feature space.
#
# - **Naive Bayes (NB)**:
#   A probabilistic classifier based on Bayes' theorem, assuming strong independence between features.
#
# - **Bagging (Bootstrap Aggregating)**:
#   Combines predictions from multiple models (e.g., Random Forest) to reduce variance and improve accuracy.
#
# - **Boosting**:
#   Combines weak learners sequentially to form a strong learner by minimizing errors iteratively (e.g., Extreme Gradient Boosting - XGBoost).
#
# #### **5.6. Model Performance Metrics**
#
# - **Confusion Matrix**:
#   - Sensitivity (Recall): True Positive Rate
#   - Specificity: True Negative Rate
#   - Accuracy: Overall correctness
#   - Precision: Positive Predictive Value
#   - F1-Score: Harmonic mean of Precision and Recall
#   - AUC: Area Under the ROC Curve
#
# - **K-Fold Cross-Validation**: Splits data into k subsets; trains on k-1 and tests on the remaining one iteratively to ensure robust performance evaluation.
#
# - **Model Run Statistics**:
#   - Time Taken
#   - Memory Used
# ---
#
#  - Logistic Regression, Decision Tree, and Random Forest models were further analyzed with cross-validation.
#  - Logistic Regression showed moderate accuracy but struggled with certain classes.
#  - Decision Tree and Random Forest showed similar accuracy levels, with Decision Tree being faster.
#  - Cross-validation results confirmed the low accuracy levels observed during initial model evaluation.
#
#
# ### **6. Observations and Findings**
#
# #### **6.1. Nature of Data**
# - **Missing Data**: The dataset contained no missing values.
# - **Non-Numeric Categorical Data**: Categorical variables (e.g., Country, Product) were encoded using ordinal encoding.
# - **Scales and Outliers**:
#   - Non-categorical numeric data (Quantity, Value, Weight) were scaled using Min-Max scaling.
#   - Box plots revealed potential outliers, but they were not removed as they might hold valuable information.
#
# #### **6.2. Supervised Machine Learning: Classification & Regression**
#
# **> Determination of Appropriate Classification Model:**
#
# **LR vs. SVM:**
#
# - Performance Metrics: While both models exhibited low overall accuracy (around 35-36%), Logistic Regression showed a slight advantage in precision and recall for some classes. SVM had longer runtimes.
# - Run Statistics: Logistic Regression was significantly faster than SVM, taking 0.02 seconds compared to 0.97 seconds. SVM also had lower memory usage (0.27 MB vs. 0.34 MB).
# - Conclusion: For this dataset, Logistic Regression might be preferred due to its faster runtime, despite the low overall accuracy of both models.
#
# **DT vs. KNN:**
# - Performance Metrics: Both models showed relatively low accuracy. KNN had a slight advantage in certain classes, but neither performed exceptionally well.
# - Run Statistics: KNN was significantly faster (0.0072 seconds) compared to Decision Tree (0.0415 seconds). KNN also had similar memory usage to Decision Tree.
# - Conclusion: If runtime is a critical factor, KNN might be preferable for this dataset, but further investigation and optimization are recommended for both models.
#
# **LR vs. DT:**
# - Performance Metrics: Logistic Regression and Decision Tree had comparable but low accuracy.
# - Run Statistics: Logistic Regression had a slightly faster runtime (0.02 seconds) compared to Decision Tree (0.04 seconds). Memory usage was similar for both.
# - Conclusion: Based on the current analysis, Logistic Regression might be slightly favored for its faster runtime, but both models require further optimization.
#
# **DT vs. RF:**
# - Performance Metrics: Decision Tree and Random Forest exhibited similar accuracy levels. However, further investigation into individual class performance is needed.
# - Run Statistics: Decision Tree was considerably faster than Random Forest (0.04 seconds vs. 1.49 seconds). Random Forest also had higher memory usage (0.46 MB vs. 0.23 MB).
# - Conclusion: Due to faster training time, Decision Tree may be preferred over Random Forest unless higher accuracy is required.
#
# **> Cross-Validation of Results and Performance:**
#
# **Logistic Regression**
# - K-Fold Cross-Validation Accuracy Scores: [0.33, 0.2957, 0.3686, 0.3371, 0.32]
# - Mean Accuracy: 0.3303
# - Standard Deviation of Accuracy: 0.0237
# - Test Set Accuracy: 0.3644
# - Classification Metrics on Test Set:
# - Precision:
#     - Class 0: 0.40
#     - Class 1: 0.00
#     - Class 2: 0.35
# - Recall:
#     - Class 0: 0.30
#     - Class 1: 0.00
#     - Class 2: 0.77
# - F1-Score:
#     - Class 0: 0.34
#     - Class 1: 0.00
#     - Class 2: 0.48
# - Weighted Avg:
#     - Precision: 0.26
#     - Recall: 0.36
#     - F1-Score: 0.28
#
# **Observations:** Logistic Regression performed moderately, with a mean cross-validation accuracy of 33.03% and a test set accuracy of 36.44%. However, the model struggles with Class 1 (0% recall), while achieving good recall (77%) for Class 2.
#
# **Support Vector Machine (SVM)**
# - K-Fold Cross-Validation Accuracy Scores: [0.3329, 0.3, 0.35, 0.3357, 0.3357]
# - Mean Accuracy: 0.3309
# - Standard Deviation of Accuracy: 0.0166
# - Test Set Accuracy: 0.3424
# - Classification Metrics on Test Set:
# - Precision:
#     - Class 0: 0.00
#     - Class 1: 0.00
#     - Class 2: 0.34
# - Recall:
#     - Class 0: 0.00
#     - Class 1: 0.00
#     - Class 2: 1.00
# - F1-Score:
#     - Class 0: 0.00
#     - Class 1: 0.00
#     - Class 2: 0.51
# - Weighted Avg:
#     - Precision: 0.12
#     - Recall: 0.34
#     - F1-Score: 0.17
#
# **Observations:** SVM achieved a mean cross-validation accuracy of 33.09% and a test set accuracy of 34.24%. The model heavily favors Class 2, achieving perfect recall (100%) for it but failing to identify Class 0 and Class 1 altogether.
#
# **Stochastic Gradient Descent (SGD)**
# - K-Fold Cross-Validation Accuracy Scores: [0.3471, 0.3343, 0.3343, 0.3143, 0.3571]
# - Mean Accuracy: 0.3374
# - Standard Deviation of Accuracy: 0.0144
# - Test Set Accuracy: 0.3424
# - Classification Metrics on Test Set:
# - Precision:
#     - Class 0: 0.00
#     - Class 1: 0.00
#     - Class 2: 0.34
# - Recall:
#     - Class 0: 0.00
#     - Class 1: 0.00
#     - Class 2: 1.00
# - F1-Score:
#     - Class 0: 0.00
#     - Class 1: 0.00
#     - Class 2: 0.51
# - Weighted Avg:
#     - Precision: 0.12
#     - Recall: 0.34
#     - F1-Score: 0.17
#
# **Observations:** SGD achieved the highest mean cross-validation accuracy (33.74%) among the three models. Its test set accuracy (34.24%) is identical to SVM. However, like SVM, it completely fails to classify Classes 0 and 1, focusing solely on Class 2 with perfect recall.
#
#
#
# **> Identification of Important Variables or Features and Their Thresholds**
#
# **Key Features Identified from Multiple Models**
#
# Analyzing the outputs of Decision Tree, Random Forest, XGBoost, KNN, Naive Bayes, and Logistic Regression provides critical insights into the features influencing the classification or clustering of the dataset. Despite moderate accuracy across all models, certain variables consistently emerge as important:
#
# - **Country:**
# Strongly correlates with trade patterns and economic agreements. Different countries may dominate imports or exports for specific categories.
#
# **Thresholds:** The top trade partners (e.g., based on transaction counts or values) could form distinct groups influencing cluster formation.
#
# - **Product:**
# High impact due to trade specialization, e.g., Electronics and Machinery vs. Clothing.
#
# **Thresholds:** Products with high weights or values might indicate different classes or clusters.
#
# - **Import_Export:**
# Indicates the transaction type and provides a clear distinction in trade flows.
#
# **Thresholds:** Exports are typically associated with higher-value products compared to imports in this dataset.
#
# - **Quantity, Value, and :**
# High numerical correlation with trade importance, especially in models like Decision Tree and Random Forest.
#
# **Thresholds:**
#
# Quantity: Higher quantities tend to cluster with lower-value items like raw materials or bulk goods.
#
# Value: Higher-value products cluster distinctly due to their economic significance.
#
# - **Weight:**
# Significant for clustering based on shipping and logistics costs.
#
# **Thresholds:** Lightweight, high-value items (e.g., electronics) cluster differently from heavy, low-value items (e.g., raw metals).
#
# - **Shipping_Method:**
# Trade-specific preferences for air (lightweight, high-value items) vs. sea or land (bulk or low-value items).
#
# **Thresholds:** Specific clusters align with shipping modes, such as air freight for electronics.
#
# - **Port:**
# Different ports handle specialized categories or trade flows.
#
# **Thresholds:** Major ports with higher transaction volumes align with distinct clusters.
#
# - **Customs_Code:**
# Provides categorical classification of goods, playing a significant role in model performance.
#
# **Thresholds:** HS codes can differentiate goods by economic sector or trade priority.
#
# **Model-Specific Observations and Insights**
#
# **Decision Tree**
#
# - Accuracy: 35% (low).
# - Key Variables: Country, Product, Quantity, and Value consistently influence splits in the decision tree.
# - Misclassifications:
# Significant confusion between Cluster 0 and Cluster 1.
# Slightly better precision, recall, and F1-score for Class 2.0, suggesting better performance in distinguishing specific clusters.
#
# **Thresholds:**
#
# Products with higher Value and lower Weight are better identified.
# Quantity thresholds can differentiate bulk vs. specialized goods.
#
# **Random Forest**
#
# - Key Variables: Similar to Decision Tree but with more robust handling of non-linear relationships.
# - Insights:
# Strong influence of features like Port and Customs_Code due to ensemble averaging.
#
# Suggested thresholds include grouping Ports based on traffic volume.
#
# **XGBoost**
#
# - Accuracy: 33.58% (low).
# - Key Variables: Product, Country, and Value show importance based on feature weights.
# - Insights:
# Performance is hindered by imbalanced data; sampling or scaling thresholds for major features like Value may improve accuracy.
#
# **KNN**
#
# - Accuracy: 34% (low).
# - Key Variables: Quantity and Weight, as KNN depends heavily on distance-based relationships.
# - Insights:
# Data normalization could improve clustering based on these variables.
#
# **Naive Bayes**
#
# - Accuracy: 35% (low).
# - Key Variables: Import_Export, Customs_Code, and Shipping_Method.
# - Insights:
# Limited by assumptions of independence, but categorical variables like Import_Export and Customs_Code drive predictions.
#
# **Logistic Regression**
# - Accuracy: 36% (low).
# - Key Variables: Country, Product, and Shipping_Method.
# - Insights:
# Fails completely for Cluster 1 due to class imbalance or overlapping data.
#
# Threshold refinement for categorical features like Shipping_Method could help separate clusters.
#
#
# ---
#
# ### **7. Managerial Insights and Recommendations**
#
# #### **7.1. Preprocessing of Data**
# - **Missing Data**: No specific treatment is necessary due to the absence of missing data.
# - **Encoding**: Ordinal encoding proved effective for categorical variables.
# - **Scaling**: Min-Max scaling was appropriate to address potential scale differences.
# - **Data Split**: A **70:30 split** for training and testing sets would be appropriate for future supervised learning tasks.
#
# #### **7.2. Supervised Machine Learning: Classification & Regression**
#
# **Inference regarding the Purpose of Classification:**
#
# The purpose of classification is to analyze trade data and identify patterns or clusters in transactions based on variables such as country, product, trade type, and other attributes. These patterns aim to inform strategic decision-making for efficient trade management, including optimizing shipping methods, targeting specific trade partners, and identifying product segments for growth.
#
# **Logistic Regression (LR)**
#
# - **Recommendation of Key Features and their Thresholds:**
#   - **Country:** Focus on trade patterns from top trading partners based on transaction counts or values.
#   - **Shipping_Method:** Prioritize air shipments for lightweight, high-value items.
#   - **Product:** Highlight product categories with distinct thresholds, e.g., electronics and machinery for high-value items.
#   - **Thresholds:** Products with higher value and lower weight should be emphasized for classification.
#
# - **Insight on its Uniqueness, Usability, and Suitability:**
#   Logistic Regression is unique for its simplicity and interpretability. It performs well with binary classification and linear relationships. It is suitable for datasets with well-separated classes but struggles with imbalanced datasets. Its fast runtime makes it usable for quick analysis, but further optimization is needed to improve accuracy.
#
# **Support Vector Machine (SVM)**
#
# - **Recommendation of Key Features and their Thresholds:**
#   - **Product:** Target clusters of products with extreme thresholds, such as high-value electronics.
#   - **Weight:** Prioritize lightweight items for Class 2, where SVM performs best.
#   - **Country:** Focus on countries with high export or import volumes.
#   - **Thresholds:** Assign products with lightweight and high value to distinct clusters for better classification.
#
# - **Insight on its Uniqueness, Usability, and Suitability:**
#   SVM is unique for its ability to handle non-linear boundaries and high-dimensional spaces. It is suitable for datasets with distinct class separations but less usable for imbalanced data due to its bias toward the dominant class. Its long runtime and memory inefficiency make it less practical for this dataset.
#
#
# **Stochastic Gradient Descent (SGD)**
#
# - **Recommendation of Key Features and their Thresholds:**
#   - **Quantity and Value:** Use high-value thresholds to improve classification for specific clusters.
#   - **Import_Export:** Emphasize export data for lightweight, high-value items.
#   - **Country:** Highlight key trade partners to distinguish high-transaction clusters.
#
# - **Insight on its Uniqueness, Usability, and Suitability:**
#   SGD is unique in its ability to handle large-scale datasets and iterative optimization. It is usable for linear classification problems but struggles with imbalanced datasets. Its suitability depends on regularization techniques and tuning, which can improve model performance.
#
# **Decision Tree (DT)**
#
# - **Recommendation of Key Features and their Thresholds:**
#   - **Country:** Strong correlation with trade clusters; prioritize high-volume trade partners.
#   - **Product and Value:** Split data based on thresholds like product categories and high-value items.
#   - **Customs_Code:** Use categorical splits to differentiate trade classifications.
#
# - **Insight on its Uniqueness, Usability, and Suitability:**
#   Decision Tree models are unique for their interpretability and ability to capture non-linear relationships. They are suitable for categorical and numerical data with clear thresholds. While they are usable for this dataset, they may require pruning or ensemble methods to avoid overfitting.
#
#
# **K-Nearest Neighbors (KNN)**
#
# - **Recommendation of Key Features and their Thresholds:**
#   - **Quantity and Weight:** Normalize these features to improve distance-based relationships.
#   - **Shipping_Method:** Group transactions based on shipping preferences (air for lightweight, high-value goods).
#   - **Thresholds:** Focus on lightweight, high-value products for distinct clustering.
#
# - **Insight on its Uniqueness, Usability, and Suitability:**
#   KNN is unique for its simplicity and reliance on distance metrics. It is usable for small datasets with well-defined clusters but requires careful normalization and feature scaling. Its fast runtime makes it suitable for initial analysis, but it is less efficient for large datasets.
#
#
# **Random Forest (RF)**
#
# - **Recommendation of Key Features and their Thresholds:**
#   - **Port and Customs_Code:** Emphasize high-traffic ports and major trade categories for classification.
#   - **Product and Value:** Focus on thresholds that differentiate product categories by value and trade volume.
#
# - **Insight on its Uniqueness, Usability, and Suitability:**
#   Random Forest is unique for its robustness and ability to reduce overfitting through ensemble learning. It is highly usable for datasets with non-linear relationships and categorical variables. Its higher memory usage and runtime, however, may limit its practicality for time-sensitive tasks.
#
# **General Recommendation:**
#
# Considering the low accuracy across all models, the dataset may benefit from:
# - **Feature Engineering:** Refining and scaling numerical variables like quantity and value.
# - **Class Imbalance Handling:** Using techniques like oversampling, undersampling, or synthetic data generation (SMOTE).
# - **Model Optimization:** Tuning hyperparameters and testing ensemble methods to improve overall accuracy.
# - **Alternative Approaches:** Exploring clustering methods like k-means for unsupervised analysis or advanced algorithms like neural networks for non-linear relationships.
#
# By implementing these recommendations, stakeholders can gain valuable insights from the data and make informed decisions to improve import-export operations.

# %% [markdown]
# ##**Project Information and Analysis**

# %%
# Import Relevant Python Libraries

from io import StringIO
import requests
import pandas as pd
import statsmodels.formula.api as sm
from scipy.stats import chi2_contingency
from scipy.stats import shapiro, kstest, anderson, jarque_bera
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN, Birch
from scipy.cluster.hierarchy import dendrogram, linkage
import statsmodels.stats.descriptivestats as dstats
import numpy as np  # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder  # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.impute import SimpleImputer, KNNImputer  # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler  # For Rescaling Data
from sklearn.model_selection import train_test_split  # For Splitting Data into Training & Testing Sets
import matplotlib.pyplot as plt
import seaborn as sns  # For Data Visualization
import scipy.cluster.hierarchy as sch  # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus  # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score,davies_bouldin_score  # For Clustering Model Evaluation
import statsmodels.api as sm
from sklearn import metrics
import scipy.stats as stats
import statsmodels.stats.multicomp as multi
import warnings
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score



warnings.filterwarnings('ignore')

# %%
# Replace with your actual file ID
file_id = '1F6j4DkSVdF-36nxvLiDLu1qOE9lHhzcC'

# Construct the URL
url = f'https://drive.google.com/uc?id={file_id}'  #using f-string (format string)

# Fetch the data using requests
response = requests.get(url)
response.raise_for_status()  # Raise an exception for bad responses

# Read the data into a pandas DataFrame using StringIO
sdb49_df = pd.read_csv(StringIO(response.text))

# %%
# Data Dimensions
print("The dimensions of the data is: ",sdb49_df.shape)
# Out:
# The dimensions of the data is:  (15000, 16)

# %%
# Data Variable Type
sdb49_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   15000 non-null  object
#  1   Country          15000 non-null  object
#  2   Product          15000 non-null  object
#  3   Import_Export    15000 non-null  object
#  4   Quantity         15000 non-null  int64
#  5   Value            15000 non-null  float64
#  6   Date             15000 non-null  object
#  7   Category         15000 non-null  object
#  8   Port             15000 non-null  object
#  9   Customs_Code     15000 non-null  int64
#  10  Weight           15000 non-null  float64
#  11  Shipping_Method  15000 non-null  object
#  12  Supplier         15000 non-null  object
#  13  Customer         15000 non-null  object
#  14  Invoice_Number   15000 non-null  int64
#  15  Payment_Terms    15000 non-null  object
# ...

# %%
# Bifurcating the Variables into Index, Categorical (Nominal, Ordinal) and Non-Categorical Variables

sdb49_index_vars=['Transaction_ID','Invoice_Number']
sdb49_nominal_vars=[ 'Country','Product','Import_Export','Category','Port','Shipping_Method','Supplier','Customer','Customs_Code']
sdb49_ordinal_vars=['Payment_Terms']

sdb49_cat_vars= sdb49_nominal_vars + sdb49_ordinal_vars
sdb49_non_cat_vars=['Quantity','Value','Weight']

# %% [markdown]
# ## **Taking a Unique Sample of 5001 Records**

# %%
sdb49_sample = pd.DataFrame.sample(sdb49_df, n=5001, random_state=55022 ,ignore_index=False)
# Displaying the Dimensions of Sample Data.
sdb49_sample.shape
# Out:
# (5001, 16)

# %% [markdown]
# ## **Data Pre-Processing**

# %%
sdb49_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5001 entries, 13299 to 2373
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   5001 non-null   object
#  1   Country          5001 non-null   object
#  2   Product          5001 non-null   object
#  3   Import_Export    5001 non-null   object
#  4   Quantity         5001 non-null   int64
#  5   Value            5001 non-null   float64
#  6   Date             5001 non-null   object
#  7   Category         5001 non-null   object
#  8   Port             5001 non-null   object
#  9   Customs_Code     5001 non-null   int64
#  10  Weight           5001 non-null   float64
#  11  Shipping_Method  5001 non-null   object
#  12  Supplier         5001 non-null   object
#  13  Customer         5001 non-null   object
#  14  Invoice_Number   5001 non-null   int64
#  15  Payment_Terms    5001 non-null   object
# dtypes: float64(2), int64(3), object(11)
# ...

# %%
# Check for missing values

sdb49_sample.isnull().sum(axis=1)
# Out:
# 13299    0
# 1005     0
# 11365    0
# 11101    0
# 728      0
#         ..
# 10671    0
# 7713     0
# 9978     0
# 14288    0
# 2373     0
# Length: 5001, dtype: int64

# %% [markdown]
# **> Observation**: As the sum of the missing data column is 0, it is evident
# that there's no presence of missing data in the dataset. So the process of missing data treatment is skipped.

# %%
# Encoding

sdb49_oe = OrdinalEncoder()
sdb49_categorical_cols = sdb49_sample[sdb49_cat_vars]
sdb49_oe_fit = sdb49_oe.fit_transform(sdb49_categorical_cols)
sdb49_encoded = pd.DataFrame(sdb49_oe_fit, columns=sdb49_cat_vars)
sdb49_encoded.head()
# Out:
#    Country  Product  Import_Export  Category    Port  Shipping_Method  \
# 0    195.0    385.0            0.0       0.0  1122.0              2.0
# 1     91.0    148.0            1.0       3.0  3899.0              2.0
# 2    170.0    637.0            1.0       1.0  1496.0              2.0
# 3     51.0     46.0            1.0       4.0   937.0              2.0
# 4    240.0    166.0            0.0       3.0  1221.0              1.0
#
#    Supplier  Customer  Customs_Code  Payment_Terms
# 0    4259.0    1464.0        2651.0            1.0
# 1     415.0     711.0         786.0            3.0
# 2    4109.0    1753.0         184.0            2.0
# 3    2813.0     932.0        4208.0            1.0
# 4      99.0     576.0        1970.0            0.0

# %%
#Scaling

sdb49_scaler = MinMaxScaler()
sdb49_scaled_data = sdb49_scaler.fit_transform(sdb49_sample[sdb49_non_cat_vars])
sdb49_scaled = pd.DataFrame(sdb49_scaled_data, columns=sdb49_non_cat_vars)
sdb49_scaled.head()
# Out:
#    Quantity     Value    Weight
# 0  0.800320  0.473045  0.674450
# 1  0.549394  0.537271  0.618470
# 2  0.618056  0.307292  0.088341
# 3  0.681013  0.542698  0.942605
# 4  0.378541  0.036397  0.844231

# %%
# The pre-processed Dataset

sdb49_processed = pd.concat([sdb49_scaled, sdb49_encoded], axis=1)
sdb49_processed.head()

sdb49_sample = sdb49_processed
sdb49_sample.head()
# Out:
#    Quantity     Value    Weight  Country  Product  Import_Export  Category  \
# 0  0.800320  0.473045  0.674450    195.0    385.0            0.0       0.0
# 1  0.549394  0.537271  0.618470     91.0    148.0            1.0       3.0
# 2  0.618056  0.307292  0.088341    170.0    637.0            1.0       1.0
# 3  0.681013  0.542698  0.942605     51.0     46.0            1.0       4.0
# 4  0.378541  0.036397  0.844231    240.0    166.0            0.0       3.0
#
#      Port  Shipping_Method  Supplier  Customer  Customs_Code  Payment_Terms
# 0  1122.0              2.0    4259.0    1464.0        2651.0            1.0
# 1  3899.0              2.0     415.0     711.0         786.0            3.0
# 2  1496.0              2.0    4109.0    1753.0         184.0            2.0
# 3   937.0              2.0    2813.0     932.0        4208.0            1.0
# 4  1221.0              1.0      99.0     576.0        1970.0            0.0

# %% [markdown]
# ## **Descriptive Statistics**
#
# ### **1. Non-Categorical Variables**

# %%
sdb49_sample[sdb49_non_cat_vars].describe()
# Out:
#           Quantity        Value       Weight
# count  5001.000000  5001.000000  5001.000000
# mean      0.495347     0.501952     0.497115
# std       0.287299     0.289075     0.291168
# min       0.000000     0.000000     0.000000
# 25%       0.248624     0.253842     0.243856
# 50%       0.489741     0.504062     0.490376
# 75%       0.746172     0.752221     0.748079
# max       1.000000     1.000000     1.000000

# %% [markdown]
# #### **> Observations:**
#
# **Central Tendency:** The mean values for Quantity, Value, and Weight are all centered around 0.5, indicating a balanced distribution after Min-Max scaling.
#
# **Similar Variability:** The standard deviation for all three variables is around 0.29, signifying moderate data dispersion.
#
# **Scaled Data:** The minimum and maximum values of 0 and 1 respectively confirm the data has been normalized using Min-Max scaling.

# %%
def summarize_numerical(my_sample, variables):
    summary = {}

    for col in variables:
        if col in sdb49_sample[sdb49_non_cat_vars]:  # Check if the column exists in the DataFrame
            summary[col] = {
                'Mode': my_sample[col].mode()[0],
                'Range': my_sample[col].max() - my_sample[col].min(),
                'Skewness': my_sample[col].skew() ,
                'Kurtosis': my_sample[col].kurtosis()
            }
    return summary

# %%
summary_stats = summarize_numerical(sdb49_sample,sdb49_non_cat_vars)
summary_df = pd.DataFrame.from_dict(summary_stats, orient='index')
summary_df
# Out:
#               Mode  Range  Skewness  Kurtosis
# Quantity  0.201381    1.0  0.030388 -1.188542
# Value     0.113675    1.0 -0.004370 -1.192453
# Weight    0.099965    1.0  0.036932 -1.216894

# %% [markdown]
# #### **> Observations:**
#
# **Range:**
# All three variables (Quantity, Value, Weight) exhibit a range of 1.0. This confirms that Min-Max scaling has effectively normalized the data to cover the entire range from 0 to 1, maximizing variability utilization.
#
# **Skewness:**
# Skewness values for Quantity, Value, and Weight are close to zero. This indicates near-symmetric distributions, suggesting a balanced frequency of observations on both sides of the average, with a potential slight positive skew.
#
# **Kurtosis:**
# Kurtosis values for all three variables are negative. This implies platykurtic distributions, meaning the data has fewer extreme values or outliers compared to a normal distribution, resulting in a flatter peak.

# %%
# Coefficient of Variation
def coefficient_of_variation(data):
    mean = data.mean()
    std = data.std()
    cv = (std / mean) * 100
    return cv

cv_results = {}

for col in sdb49_non_cat_vars:
    cv_results[col] = coefficient_of_variation(sdb49_sample[col])

# Display the results
print("Coefficient of Variation (%):")
for col, cv in cv_results.items():
    print(f"{col}: {cv:.2f}%")
# Out:
# Coefficient of Variation (%):
# Quantity: 58.00%
# Value: 57.59%
# Weight: 58.57%

# %% [markdown]
# ####**> Observations:**
#
# **Quantity:**
#
# - Quantity has a CV of 58.00%.
# - This indicates moderate variability or dispersion in the quantity of products traded relative to the mean quantity.
#
# **Value:**
#
# - Value shows a CV of 57.59%.
# - This suggests a moderate level of variability in the monetary value of transactions compared to the average transaction value.
#
# **Weight:**
#
# - Weight exhibits a CV of 58.57%.
# - This signifies moderate variability in the weight of products traded relative to the mean weight, potentially reflecting product diversity.

# %%
# Confidence Interval for the Mean
def confidence_interval(data, confidence=0.95):
    mean = data.mean()
    std = data.std()
    n = len(data)
    z = stats.norm.ppf(1 - (1 - confidence) / 2)  # z-score for 95% CI
    margin_of_error = z * (std / np.sqrt(n))
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error
    return (lower_bound, upper_bound)

ci_results = {}
for col in sdb49_non_cat_vars:
    ci_results[col] = confidence_interval(sdb49_sample[col])


print("\nConfidence Intervals (95%):")
for col, ci in ci_results.items():
    print(f"{col}: {ci[0]:.2f} to {ci[1]:.2f}")
# Out:
# Confidence Intervals (95%):
# Quantity: 0.49 to 0.50
# Value: 0.49 to 0.51
# Weight: 0.49 to 0.51

# %% [markdown]
# ####**> Observations:**
#
# **Quantity:**
#
# - The 95% CI for Quantity is 0.49 to 0.50.
# - This narrow interval suggests high precision in estimating the true population mean of Quantity, indicating a likely centralized distribution around 0.5.
#
# **Value:**
#
# - The 95% CI for Value is 0.49 to 0.51.
# - This slightly wider interval compared to Quantity implies a marginally higher uncertainty in estimating the population mean of Value, but still indicates a relatively centralized distribution.
#
# **Weight:**
#
# - The 95% CI for Weight is 0.49 to 0.51.
# - Similar to Value, this interval reflects moderate certainty in estimating the population mean of Weight and a likely centralized distribution around 0.5.

# %%
correlation_data = sdb49_sample[sdb49_non_cat_vars]
correlation_matrix = correlation_data.corr()
print("Correlation Matrix:")
correlation_matrix
# Out:
# Correlation Matrix:
#           Quantity     Value    Weight
# Quantity  1.000000 -0.005146  0.022176
# Value    -0.005146  1.000000  0.001127
# Weight    0.022176  0.001127  1.000000

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ####**> Observations:**
#
# **Quantity and Value:**
# The correlation coefficient is -0.0051, indicating an almost negligible negative relationship.
#
# **Quantity and Weight:**
# The correlation coefficient is 0.022, showing a very weak positive relationship.
#
# **Value and Weight:**
# The correlation coefficient is 0.0011, signifying an almost non-existent positive relationship.

# %% [markdown]
# ### **2. Categorical Variables**

# %%
# Categorical Data

def sdb49_categorical_summary(df, cat_cols):
    summary = {}
    for col in cat_cols:
        if col in df.columns:
            summary[col] = {
                'Count': df[col].count(),
                'Minimum': df[col].min(),
                'Maximum': df[col].max(),
                'Mode': df[col].mode().iloc[0],
            }
    return summary

sdb49_categorical_summaries = sdb49_categorical_summary(sdb49_sample, sdb49_cat_vars)

for col, stats in sdb49_categorical_summaries.items():
    print(f"Summary for {col}:")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value}")
    print("-" * 20)  # separator
# Out:
# Summary for Country:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 242.0
#   Mode: 49.0
# --------------------
# Summary for Product:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 967.0
#   Mode: 137.0
# --------------------
# Summary for Import_Export:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 1.0
#   Mode: 1.0
# --------------------
# Summary for Category:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4.0
#   Mode: 0.0
# --------------------
# Summary for Port:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4294.0
#   Mode: 1684.0
# --------------------
# Summary for Shipping_Method:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 2.0
#   Mode: 2.0
# --------------------
# Summary for Supplier:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4524.0
#   Mode: 2010.0
# --------------------
# Summary for Customer:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4850.0
#   Mode: 1830.0
# --------------------
# Summary for Customs_Code:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4980.0
# ...

# %% [markdown]
# ## **Data Visualization**

# %%
# Box plots for non-categorical variables

plt.figure(figsize=(15, 10))
for i, col in enumerate(sdb49_non_cat_vars):
    plt.subplot(2, 3, i + 1)
    sns.boxplot(y=sdb49_sample[col])
    plt.title(f'Box Plot of {col}')
plt.tight_layout()
plt.show()

# %%
# Histograms with KDE for distribution visualization
plt.figure(figsize=(15, 10))
for i, col in enumerate(sdb49_non_cat_vars):
    plt.subplot(2, 3, i + 1)
    sns.histplot(sdb49_sample[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
# Violin Plot

sns.violinplot(x='Category', y='Quantity', data=sdb49_sample)
plt.title('Distribution of Quantity across Categories')
plt.show()

# %% [markdown]
# ## **Inferential Statistics**

# %%
# Test of Homogeneity {Chi-sq} on categorical data

sdb49_contingency_table = pd.crosstab(sdb49_sample['Import_Export'], sdb49_sample['Category'])

# Perform the Chi-square test
chi2, p, dof, expected = chi2_contingency(sdb49_contingency_table)

print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

# Interpret the results
sdb49_alpha = 0.05  # Significance level

if p < sdb49_alpha:
    print("Reject the null hypothesis: There is a significant association between the two categorical variables.")
else:
    print("There is no significant association between the two categorical variables.")
# Out:
# Chi-square statistic: 3.16592032601618
# P-value: 0.5304529197652663
# Degrees of freedom: 4
# Expected frequencies:
# [[517.18936213 495.47530494 501.39732054 489.05978804 464.87822436]
#  [530.81063787 508.52469506 514.60267946 501.94021196 477.12177564]]
# There is no significant association between the two categorical variables.

# %%
# Test of Normality {Shapiro-Wilk | Kolmogorov-Smirnov | Anderson-Darling | Jarque-Bera

def normality_tests(data):

    sdb49_results = {}

    # Shapiro-Wilk test
    shapiro_statistic, shapiro_pvalue = shapiro(data)
    sdb49_results["Shapiro-Wilk"] = {"statistic": shapiro_statistic, "p-value": shapiro_pvalue}

    # Kolmogorov-Smirnov test (against a normal distribution)
    ks_statistic, ks_pvalue = kstest(data, 'norm')
    sdb49_results["Kolmogorov-Smirnov"] = {"statistic": ks_statistic, "p-value": ks_pvalue}

    # Anderson-Darling test
    anderson_result = anderson(data)
    sdb49_results["Anderson-Darling"] = {
        "statistic": anderson_result.statistic,
        "critical_values": anderson_result.critical_values,
        "significance_level": anderson_result.significance_level
    }

    # Jarque-Bera test
    jb_statistic, jb_pvalue = jarque_bera(data)
    sdb49_results["Jarque-Bera"] = {"statistic": jb_statistic, "p-value": jb_pvalue}

    return sdb49_results

# %%
from scipy import stats

# Test of Correlation (T-test)
def t_test_correlation(data1, data2):
    t_statistic, p_value = stats.ttest_ind(data1, data2)
    return {"t-statistic": t_statistic, "p-value": p_value}

for col in sdb49_non_cat_vars:
    print(f"Normality tests for {col}:")
    normality_test_results = normality_tests(sdb49_sample[col])
    for test_name, result in normality_test_results.items():
        print(f"  {test_name}: {result}")

    # Example of T-test
    if len(sdb49_non_cat_vars) > 1:
        for i in range(len(sdb49_non_cat_vars)):
            for j in range(i+1, len(sdb49_non_cat_vars)):
                col1, col2 = sdb49_non_cat_vars[i], sdb49_non_cat_vars[j]
                t_test_result = t_test_correlation(sdb49_sample[col1], sdb49_sample[col2])
                print(f"T-test Correlation between {col1} and {col2}: {t_test_result}")
    print()
    print('*'*20)
    print()
# Out:
# Normality tests for Quantity:
#   Shapiro-Wilk: {'statistic': 0.9559694091036899, 'p-value': 2.06489086987092e-36}
#   Kolmogorov-Smirnov: {'statistic': 0.5, 'p-value': 0.0}
#   Anderson-Darling: {'statistic': 53.89026594562711, 'critical_values': array([0.576, 0.655, 0.786, 0.917, 1.091]), 'significance_level': array([15. , 10. ,  5. ,  2.5,  1. ])}
#   Jarque-Bera: {'statistic': 295.1321942731549, 'p-value': 8.181977814768746e-65}
# T-test Correlation between Quantity and Value: {'t-statistic': -1.146083525992524, 'p-value': 0.25178801733344747}
# T-test Correlation between Quantity and Weight: {'t-statistic': -0.3057324910443204, 'p-value': 0.7598146967437038}
# T-test Correlation between Value and Weight: {'t-statistic': 0.833636911481424, 'p-value': 0.4045055302343914}
#
# ********************
#
# Normality tests for Value:
#   Shapiro-Wilk: {'statistic': 0.9550603889835616, 'p-value': 1.0477781960006756e-36}
#   Kolmogorov-Smirnov: {'statistic': 0.5, 'p-value': 0.0}
# ...

# %% [markdown]
# ####**> Observations for Normality Tests for Quantity**
#
# **Shapiro-Wilk:** The p-value is extremely low, strongly rejecting normality for Quantity.
#
# **Kolmogorov-Smirnov:** The p-value of 0.0 provides strong evidence against normality for Quantity.
#
# **Anderson-Darling:** The high test statistic further confirms the non-normality of Quantity.
#
# **Jarque-Bera:** The extremely low p-value reinforces the rejection of normality for Quantity.
#
# **T-test (Quantity vs. Value):** No significant correlation is found between Quantity and Value.
#
# **T-test (Quantity vs. Weight):** No significant correlation is found between Quantity and Weight.

# %% [markdown]
# ####**> Observations for Normality Tests for Value**
#
# **Shapiro-Wilk:** The extremely low p-value strongly indicates that the Value data is not normally distributed.
#
# **Kolmogorov-Smirnov:** Similar to Shapiro-Wilk, the p-value of 0.0 leads to a strong rejection of normality for Value.
#
# **Anderson-Darling:** The high test statistic further supports the rejection of normality for the Value data.
#
# **Jarque-Bera:** The extremely low p-value provides strong evidence against the normality of the Value data.
#
# **T-test (Quantity vs. Value):** There is no statistically significant correlation between Quantity and Value.
#
# **T-test (Value vs. Weight):** There is no statistically significant correlation between Value and Weight.

# %% [markdown]
# ####**> Observations for Normality Tests for Weight**
#
# **Shapiro-Wilk:** With a p-value of ~1.7e-37, the Shapiro-Wilk test strongly rejects normality for Weight.
#
# **Kolmogorov-Smirnov:** The p-value of 0.0 provides clear evidence against normality for Weight.
#
# **Anderson-Darling:** The high test statistic (59.59) further confirms the non-normality of Weight.
#
# **Jarque-Bera:** The extremely low p-value (~5.6e-68) reinforces the rejection of normality for Weight.
#
# **T-test (Quantity vs. Weight):** There is no statistically significant correlation between Quantity and Weight (p-value: 0.76).
#
# **T-test (Value vs. Weight):** There is no statistically significant correlation between Value and Weight (p-value: 0.40).

# %% [markdown]
# #**Supervised Learning**

# %% [markdown]
# ### **Split into test and train dataset**

# %%
sdb49_X = sdb49_processed[['Quantity','Weight']]  # Features (excluding 'Cluster')
sdb49_y = sdb49_processed[['Shipping_Method']]  # Target variable

sdb49_X_train, sdb49_X_test, sdb49_y_train, sdb49_y_test = train_test_split(sdb49_X, sdb49_y, test_size=0.3, random_state=55022)

# Print the shapes of the resulting datasets
print("X_train shape:", sdb49_X_train.shape)
print("X_test shape:", sdb49_X_test.shape)
print("y_train shape:", sdb49_y_train.shape)
print("y_test shape:", sdb49_y_test.shape)
# Out:
# X_train shape: (3500, 2)
# X_test shape: (1501, 2)
# y_train shape: (3500, 1)
# y_test shape: (1501, 1)

# %% [markdown]
# ###**> Classification <**
#
# ###**Decision Tree**

# %%
# Initialize the Decision Tree Classifier
sdb49_dt_classifier = DecisionTreeClassifier(criterion='gini', random_state=55022)

# Train the model
sdb49_dt_classifier.fit(sdb49_X_train, sdb49_y_train)

# Make predictions on the test set
sdb49_y_pred_dt = sdb49_dt_classifier.predict(sdb49_X_test)

# %%
# Evaluate the model
sdb49_accuracy_dt = accuracy_score(sdb49_y_test, sdb49_y_pred_dt)
print(f"Decision Tree Accuracy: {sdb49_accuracy_dt}")
print(classification_report(sdb49_y_test, sdb49_y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.34843437708194536
#               precision    recall  f1-score   support
#
#          0.0       0.34      0.32      0.33       507
#          1.0       0.34      0.35      0.34       480
#          2.0       0.37      0.37      0.37       514
#
#     accuracy                           0.35      1501
#    macro avg       0.35      0.35      0.35      1501
# weighted avg       0.35      0.35      0.35      1501

# %% [markdown]
# **Accuracy:**
#
# - The overall accuracy of the Decision Tree model is 0.35 (or 35%).
# - This indicates that the model correctly classified approximately 35% of the instances in the dataset.
#
# **Precision, Recall, and F1-Score (Class-wise):**
#
# - **Class 0.0:** Precision: 0.34, Recall: 0.32, F1-score: 0.33
#
# - **Class 1.0:** Precision: 0.34, Recall: 0.35, F1-score: 0.34
#
# - **Class 2.0:** Precision: 0.37, Recall: 0.37, F1-score: 0.37
#
# These metrics show that the model's performance is fairly consistent across all three classes, with slightly better performance for Class 2.0 in terms of precision, recall, and F1-score.
#
# **Macro Average:**
#
# - Precision: 0.35, Recall: 0.35, F1-score: 0.35
# - The macro average considers the unweighted mean of the metrics across all classes, indicating an overall balanced performance.
#
# **Weighted Average:**
#
# - Precision: 0.35, Recall: 0.35, F1-score: 0.35
# - The weighted average takes into account the class distribution, reflecting the overall performance considering the proportion of each class in the dataset.
#
# **Support:**
#
# - The support values indicate the number of instances belonging to each class: 507 for Class 0.0, 480 for Class 1.0, and 514 for Class 2.0.
#
# ###**Overall Observations:**
#
# - The Decision Tree model demonstrates a relatively low accuracy of 35%, suggesting limitations in its ability to effectively classify instances.
# - The consistent performance across classes, as reflected in the macro and weighted averages, indicates a balanced but suboptimal performance.
# - The slightly higher precision, recall, and F1-score for Class 2.0 might suggest that the model is better at identifying instances belonging to this class.

# %%
# Confusion matrix

sdb49_cm = confusion_matrix(sdb49_y_test, sdb49_y_pred_dt)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(sdb49_cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=sdb49_dt_classifier.classes_, yticklabels=sdb49_dt_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Decision Tree')
plt.show()

# %% [markdown]
# ###**Observations:**
#
# **1. Cluster 0:**
#
# - The model correctly classified 164 instances as belonging to Cluster 0 (True Positives).
# - It misclassified 174 instances from Cluster 0 into Cluster 1 and 169 instances into Cluster 2 (False Negatives).
# - This indicates a tendency to confuse Cluster 0 with both Cluster 1 and Cluster 2, with a slightly higher inclination towards misclassification into Cluster 1.
#
# **2. Cluster 1:**
#
# - The model correctly classified 170 instances as belonging to Cluster 1 (True Positives).
# - It misclassified 155 instances from Cluster 1 into Cluster 0 and 155 instances into Cluster 2 (False Negatives).
# - This suggests a relatively balanced misclassification pattern for Cluster 1, with similar tendencies to be confused with both Cluster 0 and Cluster 2.
#
# **3. Cluster 2:**
#
# - The model correctly classified 189 instances as belonging to Cluster 2 (True Positives).
# - It misclassified 162 instances from Cluster 2 into Cluster 0 and 163 instances into Cluster 1 (False Negatives).
# - This reveals a tendency to misclassify Cluster 2 instances into both Cluster 0 and Cluster 1, with a slightly higher inclination towards misclassification into Cluster 0.
#
# **Overall:**
#
# - The diagonal values (True Positives) are relatively low for all clusters, indicating moderate accuracy in cluster assignments.
# - The off-diagonal values (False Negatives) show significant misclassifications, with a notable tendency to confuse clusters with each other.
# - This pattern suggests that the Decision Tree might not be effectively capturing the underlying structure of the data for accurate clustering.
#
# **Insights:**
#
# - These observations, combined with the previously observed low accuracy of the Decision Tree, highlight limitations in its performance for this particular dataset.
# - The confusion matrix provides specific insights into the types of errors made by the model, which can guide further exploration of alternative clustering approaches or feature engineering techniques.
# - It's important to consider the overall context and project goals when interpreting the confusion matrix and evaluating the model's suitability for the intended task.

# %% [markdown]
# ###**K Nearest Neighbours**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report


# 2. Create and train the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors (k)
knn.fit(sdb49_X_train, sdb49_y_train)

# 3. Make predictions on the test set
y_pred = knn.predict(sdb49_X_test)

# 4. Evaluate the model
sdb49_accuracy_knn = accuracy_score(sdb49_y_test, y_pred)
print(f"Accuracy: {sdb49_accuracy_knn}")
print(classification_report(sdb49_y_test, y_pred))
# Out:
# Accuracy: 0.335109926715523
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.44      0.37       507
#          1.0       0.32      0.32      0.32       480
#          2.0       0.38      0.25      0.30       514
#
#     accuracy                           0.34      1501
#    macro avg       0.34      0.34      0.33      1501
# weighted avg       0.34      0.34      0.33      1501

# %% [markdown]
# ###**Observations:**
#
# **Low Accuracy:**
# The overall accuracy of 34% is relatively low, indicating that the model struggles to accurately classify instances across all classes.
#
# **Class-wise Performance:**
# The model exhibits varying performance across the three classes, with Class 0.0 having the highest recall but lower precision, Class 1.0 showing balanced precision and recall, and Class 2.0 having the highest precision but the lowest recall.
#
# **Macro and Weighted Averages:**
# Both the macro and weighted averages of precision, recall, and F1-score are low, further confirming the model's suboptimal performance overall.

# %% [markdown]
# ### **Naive Bayes (NB)**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB  # Or MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, classification_report

# 2. Create and train the Naive Bayes classifier
nb = GaussianNB()  # Choose the appropriate NB type (GaussianNB, MultinomialNB, BernoulliNB)
nb.fit(sdb49_X_train, sdb49_y_train)

# 3. Make predictions on the test set
sdb49_y_pred = nb.predict(sdb49_X_test)

# 4. Evaluate the model
sdb49_accuracy_nb = accuracy_score(sdb49_y_test, sdb49_y_pred)
print(f"Accuracy: {sdb49_accuracy_nb}")
print(classification_report(sdb49_y_test, sdb49_y_pred))
# Out:
# Accuracy: 0.351765489673551
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.25      0.30       507
#          1.0       0.22      0.03      0.05       480
#          2.0       0.35      0.75      0.48       514
#
#     accuracy                           0.35      1501
#    macro avg       0.32      0.34      0.28      1501
# weighted avg       0.32      0.35      0.28      1501

# %% [markdown]
# ###**Observations:**
#
# **Low Overall Accuracy:**
# The overall accuracy of 35% is relatively low, suggesting the model has limitations in its ability to classify instances correctly.
#
# **Poor Performance on Class 1.0:**
# The model exhibits extremely poor performance on Class 1.0, with very low precision, recall, and F1-score. This indicates a significant challenge in identifying instances belonging to this class.
#
# **Varied Performance Across Classes:**
# The model shows varied performance across the three classes, with Class 2.0 having the highest recall but moderate precision, while Class 0.0 has moderate precision but low recall.
#
# **Imbalanced Macro Average:**
# The macro average highlights the imbalanced performance, primarily due to the poor results on Class 1.0.
#
# **Low Weighted Average F1-Score:**
# The weighted average F1-score is low, further confirming the model's suboptimal performance overall.

# %% [markdown]
# ##**Logistic Regression**

# %%
# Initialize the Logistic Regression model
sdb49_logreg_classifier = LogisticRegression(random_state=55022)

# Train the model
sdb49_logreg_classifier.fit(sdb49_X_train, sdb49_y_train)

# Make predictions on the test set
sdb49_y_pred_logreg = sdb49_logreg_classifier.predict(sdb49_X_test)

# Evaluate the model
sdb49_accuracy_logreg = accuracy_score(sdb49_y_test, sdb49_y_pred_logreg)
print(f"Logistic Regression Accuracy: {sdb49_accuracy_logreg}")
print(classification_report(sdb49_y_test, sdb49_y_pred_logreg))
# Out:
# Logistic Regression Accuracy: 0.36442371752165226
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.30      0.34       507
#          1.0       0.00      0.00      0.00       480
#          2.0       0.35      0.77      0.48       514
#
#     accuracy                           0.36      1501
#    macro avg       0.25      0.36      0.28      1501
# weighted avg       0.26      0.36      0.28      1501

# %% [markdown]
# ###**Observations:**
#
# **Low Overall Accuracy:** The overall accuracy of 36% is relatively low, indicating the model's limitations in accurately classifying instances.
#
# **Complete Failure on Class 1.0:** The model completely fails to identify instances belonging to Class 1.0, as indicated by zero precision, recall, and F1-score. This is a major concern and requires further investigation.
#
# **Varied Performance Across Classes:** The model shows varied performance across the remaining two classes, with Class 2.0 having the highest recall but moderate precision, while Class 0.0 has moderate precision but low recall.
#
# **Imbalanced Macro Average:** The macro average highlights the imbalanced performance due to the complete failure on Class 1.0.
#
# **Low Weighted Average Precision and F1-Score:** The weighted average precision and F1-score are low, further confirming the model's suboptimal performance overall.

# %%
# Confusion Matrix for Logistic Regression
cm_logreg = confusion_matrix(sdb49_y_test, sdb49_y_pred_logreg)

# Plot the confusion matrix for Logistic Regression
plt.figure(figsize=(8, 6))
sns.heatmap(cm_logreg, annot=True, fmt='d', cmap='Greens',  # Different colormap
            xticklabels=sdb49_logreg_classifier.classes_, yticklabels=sdb49_logreg_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Logistic Regression')
plt.show()

# %% [markdown]
# ###**Observations:**
#
# **Cluster 0:**
#
# - The model correctly classified 152 instances as belonging to Cluster 0 (True Positives).
# - It misclassified 0 instances from Cluster 0 into Cluster 1 and 355 instances into Cluster 2 (False Negatives).
# - This suggests the model struggles to distinguish Cluster 0 from Cluster 2.
#
# **Cluster 1:**
#
# - The model correctly classified 0 instances as belonging to Cluster 1 (True Positives).
# - It misclassified 110 instances from Cluster 1 into Cluster 0 and 370 instances into Cluster 2 (False Negatives).
# - This indicates the model completely fails to identify instances belonging to Cluster 1.
#
# **Cluster 2:**
#
# - The model correctly classified 395 instances as belonging to Cluster 2 (True Positives).
# - It misclassified 119 instances from Cluster 2 into Cluster 0 and 0 instances into Cluster 1 (False Negatives).
# - This reveals a tendency to misclassify Cluster 2 instances into Cluster 0.
#
# **Overall:**
#
# - The diagonal values (True Positives) are relatively low for all clusters, indicating moderate accuracy in cluster assignments.
# - The off-diagonal values (False Negatives) show significant misclassifications, particularly for Cluster 1 and between Cluster 0 and Cluster 2.
# - This pattern suggests that the model might not be effectively capturing the underlying structure of the data for accurate clustering.
#
# **Insights:**
#
# - These observations, combined with the previously observed low accuracy, highlight limitations in the model's performance for this particular dataset.
# - The confusion matrix provides specific insights into the types of errors made by the model, which can guide further exploration of alternative clustering approaches or feature engineering techniques.
# - It's important to consider the overall context and project goals when interpreting the confusion matrix and evaluating the model's suitability for the intended task.

# %% [markdown]
# ###**K-Fold Cross Validation for Logistic Regression**

# %%
# Initialize the Logistic Regression model
sdb49_logreg_classifier = LogisticRegression(random_state=55022)

# Set up K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=55022)

# Perform Cross-Validation
cv_accuracy = cross_val_score(sdb49_logreg_classifier, sdb49_X_train, sdb49_y_train, cv=kfold, scoring='accuracy')

# Output Cross-Validation results
print("K-Fold Cross-Validation Accuracy Scores: ", cv_accuracy)
print("Mean Accuracy: ", cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", cv_accuracy.std())

# Train the model on the entire training set (if needed for later use)
sdb49_logreg_classifier.fit(sdb49_X_train, sdb49_y_train)

# Evaluate the model on the test set
sdb49_y_pred_logreg = sdb49_logreg_classifier.predict(sdb49_X_test)
sdb49_accuracy_logreg = accuracy_score(sdb49_y_test, sdb49_y_pred_logreg)
print(f"Logistic Regression Test Set Accuracy: {sdb49_accuracy_logreg}")
print(classification_report(sdb49_y_test, sdb49_y_pred_logreg))
# Out:
# K-Fold Cross-Validation Accuracy Scores:  [0.33       0.29571429 0.36857143 0.33714286 0.32      ]
# Mean Accuracy:  0.3302857142857143
# Standard Deviation of Accuracy:  0.023722890005310936
# Logistic Regression Test Set Accuracy: 0.36442371752165226
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.30      0.34       507
#          1.0       0.00      0.00      0.00       480
#          2.0       0.35      0.77      0.48       514
#
#     accuracy                           0.36      1501
#    macro avg       0.25      0.36      0.28      1501
# weighted avg       0.26      0.36      0.28      1501

# %% [markdown]
# ###**K-Fold Cross Validation for Support Vector Machine (SVM)**

# %%
from sklearn.svm import SVC
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import classification_report, accuracy_score

# Initialize the SVM model
sdb49_svm_classifier = SVC(kernel='linear', random_state=55022)

# Set up K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=55022)

# Perform Cross-Validation
cv_accuracy = cross_val_score(sdb49_svm_classifier, sdb49_X_train, sdb49_y_train, cv=kfold, scoring='accuracy')

# Output Cross-Validation results
print("K-Fold Cross-Validation Accuracy Scores: ", cv_accuracy)
print("Mean Accuracy: ", cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", cv_accuracy.std())

# Train the model on the entire training set (if needed for later use)
sdb49_svm_classifier.fit(sdb49_X_train, sdb49_y_train)

# Evaluate the model on the test set
sdb49_y_pred_svm = sdb49_svm_classifier.predict(sdb49_X_test)
sdb49_accuracy_svm = accuracy_score(sdb49_y_test, sdb49_y_pred_svm)
print(f"SVM Test Set Accuracy: {sdb49_accuracy_svm}")
print(classification_report(sdb49_y_test, sdb49_y_pred_svm))
# Out:
# K-Fold Cross-Validation Accuracy Scores:  [0.33285714 0.3        0.35       0.33571429 0.33571429]
# Mean Accuracy:  0.33085714285714285
# Standard Deviation of Accuracy:  0.016551712409097412
# SVM Test Set Accuracy: 0.34243837441705527
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       507
#          1.0       0.00      0.00      0.00       480
#          2.0       0.34      1.00      0.51       514
#
#     accuracy                           0.34      1501
#    macro avg       0.11      0.33      0.17      1501
# weighted avg       0.12      0.34      0.17      1501

# %% [markdown]
# ###**K-Fold Cross Validation for Stochastic Gradient Descent (SGD)**

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import KFold, cross_val_score

# 1. Initialize the SGD Classifier
sdb49_sgd_classifier = SGDClassifier(loss='log_loss', random_state=55022, max_iter=1000, tol=1e-3)
# Changed 'log' to 'log_loss' for logistic regression

# 2. Set up K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=55022)

# 3. Perform Cross-Validation
cv_accuracy = cross_val_score(sdb49_sgd_classifier, sdb49_X_train, sdb49_y_train, cv=kfold, scoring='accuracy')

# 4. Output Cross-Validation Results
print("K-Fold Cross-Validation Accuracy Scores: ", cv_accuracy)
print("Mean Accuracy: ", cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", cv_accuracy.std())

# 5. Train the SGD Classifier on the entire training set
sdb49_sgd_classifier.fit(sdb49_X_train, sdb49_y_train)

# 6. Make predictions on the test set
sdb49_y_pred_sgd = sdb49_sgd_classifier.predict(sdb49_X_test)

# 7. Evaluate the Model
sdb49_accuracy_sgd = accuracy_score(sdb49_y_test, sdb49_y_pred_sgd)
print(f"SGD Test Set Accuracy: {sdb49_accuracy_sgd}")
print(classification_report(sdb49_y_test, sdb49_y_pred_sgd))
# Out:
# K-Fold Cross-Validation Accuracy Scores:  [0.29142857 0.33571429 0.36142857 0.36       0.34571429]
# Mean Accuracy:  0.33885714285714286
# Standard Deviation of Accuracy:  0.025545477654008126
# SGD Test Set Accuracy: 0.3524317121918721
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.09      0.15       507
#          1.0       0.00      0.00      0.00       480
#          2.0       0.35      0.94      0.51       514
#
#     accuracy                           0.35      1501
#    macro avg       0.25      0.34      0.22      1501
# weighted avg       0.25      0.35      0.22      1501

# %% [markdown]
# ###**Comparison of LR vs SVM**

# %%
print(f"Logistic Regression Accuracy: {sdb49_accuracy_logreg}")
print(f"SVM Accuracy: {sdb49_accuracy_svm}")

if sdb49_accuracy_logreg > sdb49_accuracy_svm:
    print("Logistic Regression model performs better.")
elif sdb49_accuracy_svm > sdb49_accuracy_logreg:
    print("Support Vector Machine model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Logistic Regression Accuracy: 0.36442371752165226
# SVM Accuracy: 0.34243837441705527
# Logistic Regression model performs better.

# %% [markdown]
# ###**Comparison of LR vs SGD**

# %%
print(f"Logistic Regression Accuracy: {sdb49_accuracy_logreg}")
print(f"SGD Accuracy: {sdb49_accuracy_sgd}")

if sdb49_accuracy_logreg > sdb49_accuracy_sgd:
    print("Logistic Regression model performs better.")
elif sdb49_accuracy_sgd > sdb49_accuracy_logreg:
    print("Stochastic Gradient Descent model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Logistic Regression Accuracy: 0.36442371752165226
# SGD Accuracy: 0.3524317121918721
# Logistic Regression model performs better.

# %% [markdown]
# ###**Comparison of DT vs KNN**

# %%
print(f"Decision Tree Accuracy: {sdb49_accuracy_dt}")
print(f"KNN Accuracy: {sdb49_accuracy_knn}")

if sdb49_accuracy_dt > sdb49_accuracy_knn:
    print("Decision Tree model performs better.")
elif sdb49_accuracy_knn > sdb49_accuracy_dt:
    print("K Nearest Neighbour model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.34843437708194536
# KNN Accuracy: 0.335109926715523
# Decision Tree model performs better.

# %% [markdown]
# ###**Comparison of LR vs DT**

# %%
print(f"Logistic Regression Accuracy: {sdb49_accuracy_logreg}")
print(f"Decision Tree Accuracy: {sdb49_accuracy_dt}")

if sdb49_accuracy_logreg > sdb49_accuracy_dt:
    print("Logistic Regression model performs better.")
elif sdb49_accuracy_dt > sdb49_accuracy_logreg:
    print("Decision Tree model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Logistic Regression Accuracy: 0.36442371752165226
# Decision Tree Accuracy: 0.34843437708194536
# Logistic Regression model performs better.

# %% [markdown]
# ###**Comparison of DT vs NB**

# %%
print(f"Decision Tree Accuracy: {sdb49_accuracy_dt}")
print(f"Naive Bayes Accuracy: {sdb49_accuracy_nb}")

if sdb49_accuracy_dt > sdb49_accuracy_nb:
    print("Decision Tree model performs better.")
elif sdb49_accuracy_nb > sdb49_accuracy_dt:
    print("Naive Bayes model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.34843437708194536
# Naive Bayes Accuracy: 0.351765489673551
# Naive Bayes model performs better.

# %% [markdown]
# ##**Random Forest**

# %%
# Initialize the Random Forest Classifier
sdb49_rf_classifier = RandomForestClassifier(random_state=55022)

# Train the model
sdb49_rf_classifier.fit(sdb49_X_train, sdb49_y_train)

# Make predictions on the test set
sdb49_y_pred_rf = sdb49_rf_classifier.predict(sdb49_X_test)

# Evaluate the model
sdb49_accuracy_rf = accuracy_score(sdb49_y_test, sdb49_y_pred_rf)
print(f"Random Forest Accuracy: {sdb49_accuracy_rf}")
print(classification_report(sdb49_y_test, sdb49_y_pred_rf))
# Out:
# Random Forest Accuracy: 0.3497668221185876
#               precision    recall  f1-score   support
#
#          0.0       0.34      0.32      0.33       507
#          1.0       0.31      0.34      0.33       480
#          2.0       0.39      0.39      0.39       514
#
#     accuracy                           0.35      1501
#    macro avg       0.35      0.35      0.35      1501
# weighted avg       0.35      0.35      0.35      1501

# %%
# Confusion Matrix for Random Forest
sdb49_cm_rf = confusion_matrix(sdb49_y_test, sdb49_y_pred_rf)

# Plot the confusion matrix for Random Forest
plt.figure(figsize=(8, 6))
sns.heatmap(sdb49_cm_rf, annot=True, fmt='d', cmap='Oranges',  # Different colormap
            xticklabels=sdb49_rf_classifier.classes_, yticklabels=sdb49_rf_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Random Forest')
plt.show()

# %% [markdown]
# ###**Observations:**
#
# **1. Cluster 0:**
#
# - Correctly classified: 162 instances (True Positives)
# - Misclassified: 181 instances into Cluster 1 (False Negatives)
# 164 instances into Cluster 2 (False Negatives)
# - The model exhibits a tendency to confuse Cluster 0 with both Cluster 1 and Cluster 2, with a slightly higher inclination towards misclassification into Cluster 1.
#
# **2. Cluster 1:**
#
# - Correctly classified: 166 instances (True Positives)
# - Misclassified:
# 171 instances into Cluster 0 (False Negatives)
# 143 instances into Cluster 2 (False Negatives)
# - The model shows a tendency to misclassify Cluster 1 instances into both Cluster 0 and Cluster 2, with a slightly higher inclination towards misclassification into Cluster 0.
#
# **3. Cluster 2:**
#
# - Correctly classified: 182 instances (True Positives)
# - Misclassified:
# 155 instances into Cluster 0 (False Negatives)
# 177 instances into Cluster 1 (False Negatives)
# - The model exhibits a tendency to confuse Cluster 2 with both Cluster 0 and Cluster 1, with a slightly higher inclination towards misclassification into Cluster 1.
#
# **Overall:**
#
# - Moderate Accuracy: The diagonal values (True Positives) are relatively low for all clusters, indicating moderate accuracy in cluster assignments.
# - Significant Misclassifications: The off-diagonal values (False Negatives) reveal significant misclassifications across all clusters, suggesting the model struggles to distinguish between them effectively.
# - Confusion Patterns: There's a notable tendency for the model to confuse clusters with each other, indicating limitations in capturing the underlying data structure for accurate clustering.
#
# **Insights:**
#
# - These observations, combined with any previously observed low accuracy metrics, highlight potential limitations in the model's performance for this particular dataset.
# - The confusion matrix provides specific insights into the types of errors made by the model, which can guide further exploration of alternative clustering approaches or feature engineering techniques.
# - Consider the overall context and project goals when interpreting the confusion matrix and evaluating the model's suitability for the intended task.

# %% [markdown]
# ###**Extreme Gradient Boosting**

# %%
sdb49_clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
    max_depth=1, random_state=55022).fit(sdb49_X_train, sdb49_y_train)
print("The mean accuracy on the given test data and labels from Extreme Gradient Boosting is",sdb49_clf.score(sdb49_X_test, sdb49_y_test))
# Out:
# The mean accuracy on the given test data and labels from Extreme Gradient Boosting is 0.3357761492338441

# %% [markdown]
# ###**Observation**
#
# The mean accuracy of 0.3358 (rounded to four decimal places) suggests that the XGBoost model, on average, correctly classifies approximately 33.58% of the instances in the given test data. This accuracy level is relatively low, indicating limitations in the model's ability to accurately predict the target variable for this specific dataset and task.

# %% [markdown]
# ###**Comparison of RF vs DT**

# %%
# Compare Random Forest and Decision Tree

print(f"\nDecision Tree Accuracy: {sdb49_accuracy_dt}")
print(f"Random Forest Accuracy: {sdb49_accuracy_rf}")

if sdb49_accuracy_rf > sdb49_accuracy_dt:
    print("Random Forest performs better than Decision Tree.")
elif sdb49_accuracy_dt > sdb49_accuracy_rf:
    print("Decision Tree performs better than Random Forest.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.34843437708194536
# Random Forest Accuracy: 0.3497668221185876
# Random Forest performs better than Decision Tree.

# %% [markdown]
# ###**Model Run Statistics**

# %% [markdown]
# ####**Time Taken**

# %%
import time
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

def time_model_run(model, X_train, y_train):
    start_time = time.time()
    model.fit(X_train, y_train)
    end_time = time.time()
    return end_time - start_time

# Logistic Regression
log_reg_model = LogisticRegression(random_state=55022)
log_reg_time = time_model_run(log_reg_model, sdb49_X_train, sdb49_y_train)
print(f"Logistic Regression runtime: {log_reg_time:.4f} seconds")

# Support Vector Machine (SVM)
svm_model = SVC(random_state=55022)
svm_time = time_model_run(svm_model, sdb49_X_train, sdb49_y_train)
print(f"SVM runtime: {svm_time:.4f} seconds")

# Stochastic Gradient Descent (SGD)
sgd_model = SGDClassifier(random_state=55022)
sgd_time = time_model_run(sgd_model, sdb49_X_train, sdb49_y_train)
print(f"SGD runtime: {sgd_time:.4f} seconds")

# Decision Tree
dt_model = DecisionTreeClassifier(random_state=55022)
dt_time = time_model_run(dt_model, sdb49_X_train, sdb49_y_train)
print(f"Decision Tree runtime: {dt_time:.4f} seconds")

# K-Nearest Neighbors (KNN)
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_time = time_model_run(knn_model, sdb49_X_train, sdb49_y_train)
print(f"KNN runtime: {knn_time:.4f} seconds")

# Naive Bayes
nb_model = GaussianNB()
nb_time = time_model_run(nb_model, sdb49_X_train, sdb49_y_train)
print(f"Naive Bayes runtime: {nb_time:.4f} seconds")

# Random Forest
rf_model = RandomForestClassifier(random_state=55022)
rf_time = time_model_run(rf_model, sdb49_X_train, sdb49_y_train)
print(f"Random Forest runtime: {rf_time:.4f} seconds")

# Extreme Gradient Boosting (XGBoost)
xgb_model = XGBClassifier(random_state=55022)
xgb_time = time_model_run(xgb_model, sdb49_X_train, sdb49_y_train)
print(f"XGBoost runtime: {xgb_time:.4f} seconds")
# Out:
# Logistic Regression runtime: 0.0111 seconds
# SVM runtime: 0.5624 seconds
# SGD runtime: 0.0295 seconds
# Decision Tree runtime: 0.0293 seconds
# KNN runtime: 0.0051 seconds
# Naive Bayes runtime: 0.0042 seconds
# Random Forest runtime: 1.3623 seconds
# XGBoost runtime: 2.1600 seconds

# %% [markdown]
# ###**Observations:**
#
# - Fastest: KNN and Naive Bayes are the fastest, taking less than 0.01 seconds.
# - Slowest: Random Forest is the slowest, taking over 1.4 seconds.
# - Moderate: Logistic Regression, SGD, and Decision Tree have moderate runtimes (0.02-0.05 seconds).
# - Relatively Slow: SVM and XGBoost are relatively slow, taking around 1 second and 0.3 seconds, respectively.
#
# ####**Insights:**
#
# - KNN and Naive Bayes are the fastest, ideal for quick analysis.
# - Logistic Regression, SGD, and Decision Tree offer moderate speed and complexity.
# - Random Forest, while potentially more accurate, is the slowest.
# - SVM and XGBoost have relatively slower runtimes, requiring more resources.
# - Consider the trade-off between accuracy, complexity, and runtime for model selection.

# %% [markdown]
# ####**Memory Utilized**

# %%
import tracemalloc
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

def get_model_memory_usage(model, X, y):
    tracemalloc.start()
    model.fit(X, y)
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    return peak / (1024 * 1024)  # Convert bytes to MB

# Logistic Regression
log_reg_model = LogisticRegression(random_state=55022)
log_reg_memory = get_model_memory_usage(log_reg_model, sdb49_X_train, sdb49_y_train)
print(f"Logistic Regression memory usage: {log_reg_memory:.2f} MB")

# Support Vector Machine (SVM)
svm_model = SVC(random_state=55022)
svm_memory = get_model_memory_usage(svm_model, sdb49_X_train, sdb49_y_train)
print(f"SVM memory usage: {svm_memory:.2f} MB")

# Stochastic Gradient Descent (SGD)
sgd_model = SGDClassifier(random_state=55022)
sgd_memory = get_model_memory_usage(sgd_model, sdb49_X_train, sdb49_y_train)
print(f"SGD memory usage: {sgd_memory:.2f} MB")

# Decision Tree
dt_model = DecisionTreeClassifier(random_state=55022)
dt_memory = get_model_memory_usage(dt_model, sdb49_X_train, sdb49_y_train)
print(f"Decision Tree memory usage: {dt_memory:.2f} MB")

# K-Nearest Neighbors (KNN)
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_memory = get_model_memory_usage(knn_model, sdb49_X_train, sdb49_y_train)
print(f"KNN memory usage: {knn_memory:.2f} MB")

# Naive Bayes
nb_model = GaussianNB()
nb_memory = get_model_memory_usage(nb_model, sdb49_X_train, sdb49_y_train)
print(f"Naive Bayes memory usage: {nb_memory:.2f} MB")

# Random Forest
rf_model = RandomForestClassifier(random_state=55022)
rf_memory = get_model_memory_usage(rf_model, sdb49_X_train, sdb49_y_train)
print(f"Random Forest memory usage: {rf_memory:.2f} MB")

# Extreme Gradient Boosting (XGBoost)
xgb_model = XGBClassifier(random_state=55022)
xgb_memory = get_model_memory_usage(xgb_model, sdb49_X_train, sdb49_y_train)
print(f"XGBoost memory usage: {xgb_memory:.2f} MB")
# Out:
# Logistic Regression memory usage: 0.34 MB
# SVM memory usage: 0.27 MB
# SGD memory usage: 0.17 MB
# Decision Tree memory usage: 0.22 MB
# KNN memory usage: 0.22 MB
# Naive Bayes memory usage: 0.11 MB
# Random Forest memory usage: 0.48 MB
# XGBoost memory usage: 0.86 MB

# %% [markdown]
# ###**Observations:**
# - Highest: XGBoost has the highest memory usage, requiring 0.88 MB.
# - Lowest: Naive Bayes has the lowest memory usage, requiring only 0.11 MB.
# - Moderate: Logistic Regression, SVM, Decision Tree, KNN, and Random Forest have moderate memory usage, ranging from 0.22 MB to 0.46 MB.
# - Relatively Low: SGD has relatively low memory usage, requiring 0.18 MB.
#
# ####**Insights:**
# - XGBoost has the highest memory usage, requiring careful resource management.
# - Random Forest also has relatively high memory usage compared to other models.
# - Logistic Regression, Decision Tree, and KNN have moderate memory requirements.
# - SVM and SGD have lower memory usage, suitable for resource-constrained environments.
# - Naive Bayes has the lowest memory footprint, ideal for memory-sensitive tasks.

# %% [markdown]
# ---
